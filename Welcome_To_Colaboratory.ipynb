# %% [markdown]
# ### ***Image shape using wordcloud in Python Programming ** *italicized text* *italicized text*

# %% [markdown]
# **bold text**

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.6/dist-packages (1.5.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from wordcloud) (7.0.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from wordcloud) (1.18.5)

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dfee60ec-d9d0-466c-aa4d-daca03f95328" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dfee60ec-d9d0-466c-aa4d-daca03f95328">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving winemag-data-130k-v2.csv to winemag-data-130k-v2.csv

# %%
df = pd.read_csv("winemag-data-130k-v2.csv", index_col=0)

# %%
df.head()
# Out:
#     country  ...               winery
# 0     Italy  ...              Nicosia
# 1  Portugal  ...  Quinta dos Avidagos
# 2        US  ...            Rainstorm
# 3        US  ...           St. Julian
# 4        US  ...         Sweet Cheeks
#
# [5 rows x 13 columns]

# %%
text = " ".join(review for review in df.description)
print ("There are {} words in the combination of all review.".format(len(text)))
# Out:
# There are 31661073 words in the combination of all review.

# %%
wordcl = WordCloud().generate(text)
plt.imshow(wordcl, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
stopwords = set(STOPWORDS)

# %%
stopwords.update("drink","now","cherry","wine","made","the", "flavor")

# %%
wordcl = WordCloud(stopwords=stopwords, background_color="white", max_font_size=50, max_words= 2000).generate(text)
plt.figure(figsize=(10, 8))
plt.imshow(wordcl, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4702ceb9-1371-4300-8d66-0151bae09549" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4702ceb9-1371-4300-8d66-0151bae09549">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HourGlass.jpg to HourGlass.jpg

# %%
mask = np.array(Image.open("HourGlass.jpg"))

# %%
wc = WordCloud(background_color='black', mask=mask, mode='RGB', 
              width=1000, max_words=200, height=1000,
              random_state=1)
wc.generate(text)
plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation='bilinear')
plt.tight_layout(pad=0)
plt.axis('off')
plt.show()

# %%
wc = WordCloud(background_color='black', mask=mask, mode='RGB', 
               color_func=lambda *args, **kwargs: "white", 
              width=1000, max_words=200, height=1000,
              random_state=1)
wc.generate(text)
plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation='bilinear')
plt.tight_layout(pad=0)
plt.axis('off')
plt.show()

# %%
wc = WordCloud(background_color='white', mask=mask, mode='RGB',
               width=1000, max_words=1000, height=1000,
               random_state=1, contour_width=1, contour_color='steelblue')
wc.generate(text)
plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation='bilinear')
plt.tight_layout(pad=0)
plt.axis('off')
plt.show()

# %%
bottles = np.array(Image.open("img/bottle size.png"))
wc = WordCloud(background_color='white', mask=bottles)
wc.generate(text)
image_colors = ImageColorGenerator(bottles)
wc.recolor(color_func=image_colors)
plt.figure(figsize=[10, 10])
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-2c9bbac55a54> in <module>()
# ----> 1 bottles = np.array(Image.open("img/bottle size.png"))
#       2 wc = WordCloud(background_color='white', mask=bottles)
#       3 wc.generate(text)
#       4 image_colors = ImageColorGenerator(bottles)
#       5 wc.recolor(color_func=image_colors)
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: 'img/bottle size.png'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-38fa033d-ea5e-44e0-9fc2-074d7119e907" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38fa033d-ea5e-44e0-9fc2-074d7119e907">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Bottles.png to Bottles.png

# %%
bottles = np.array(Image.open("Bottles.png"))
wc = WordCloud(background_color='white', mask=bottles)
wc.generate(text)
image_colors = ImageColorGenerator(bottles)
wc.recolor(color_func=image_colors)
plt.figure(figsize=[10, 10])
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wc = WordCloud(background_color="grey", mask=bottles,
              contour_width=1, contour_color='green')
wc.generate(text)
image_colors = ImageColorGenerator(bottles)
wc.recolor(color_func=image_colors)
plt.figure(figsize=(10,10))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wc = WordCloud(background_color="white", mask=bottles,
              contour_width=1, contour_color='red')
wc.generate(text)
image_colors = ImageColorGenerator(bottles)
wc.recolor(color_func=image_colors)
plt.figure(figsize=(15,15))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6e6d1dc4-7087-4703-ba48-9920ff9bd9f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6e6d1dc4-7087-4703-ba48-9920ff9bd9f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving girl_body.jpg to girl_body.jpg

# %%
bottles = np.array(Image.open("girl_body.jpg"))
wc = WordCloud(background_color='white', mask=bottles)
wc.generate(text)
image_colors = ImageColorGenerator(bottles)
wc.recolor(color_func=image_colors)
plt.figure(figsize=[10, 10])
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6fdbc4a5-04d2-40e9-b7e7-5ec74675dd1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6fdbc4a5-04d2-40e9-b7e7-5ec74675dd1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving girl_body_1.png to girl_body_1.png

# %%
bottles = np.array(Image.open("girl_body_1.png"))
wc = WordCloud(background_color='white', mask=bottles)
wc.generate(text)
image_colors = ImageColorGenerator(bottles)
wc.recolor(color_func=image_colors)
plt.figure(figsize=[10, 10])
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
